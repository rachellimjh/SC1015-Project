# %% [markdown]
# ## Importing the basic libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ## Importing the communities dataset

# %%
read_file = pd.read_csv ('communities.data')
read_file.to_csv ('communities.csv', index=False)

# %%
with open('communities.txt', 'r') as f:
    headers = [line.strip() for line in f.readlines()] # read header names from file into a list

communitiesData = pd.read_csv('communities.csv', header=None) # specify that there are no headers in the original file
communitiesData.columns = headers # set the column headers to the list of headers
communitiesData.to_csv('communities.csv', index=False) # write the DataFrame with headers to the same CSV file

communitiesData.head()
# Out:
#    state  county  community  communityname  fold  population  householdsize  \
# 0  state  county  community  communityname  fold  population  householdsize
# 1  state  county  community  communityname  fold  population  householdsize
# 2  state  county  community  communityname  fold  population  householdsize
# 3  state  county  community  communityname  fold  population  householdsize
# 4  state  county  community  communityname  fold  population  householdsize
#
#    racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens  \
# 0  racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens
# 1  racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens
# 2  racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens
# 3  racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens
# 4  racePctblack  racePctWhite  racePctAsian  ...  LandArea  PopDens
#
#    PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# ...
